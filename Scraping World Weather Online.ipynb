# %%
bf3dfbb1d8814f36939160059220803

# %%
import sys
# !{sys.executable} -m pip install wwo-hist

# %%
import wwo_hist

# %%
key='bf3dfbb1d8814f36939160059220803' # API key obtained from https://www.worldweatheronline.com/
locations=['Kuala+Lumpur'] # list of strings containg US Zipcode, UK Postcode, Canada Postalcode, IP address, Latitude/Longitude (decimal degree) or city name  
start='08-Mar-2012' # date when desired scraping period starts; preferred date format: 'dd-mmm-yyyy'
end='08-Mar-2022' # date when desired scraping period ends; preferred date format: 'dd-mmm-yyyy
freq=24 # frequency between observations; possible values 1 (1 hour), 3 (3 hours), 6 (6 hours), 12 (12 hours (day/night)) or 24 (daily averages)

# %%
hist_weather_data = wwo_hist.retrieve_hist_data(
    api_key=key, 
    location_list=locations, 
    start_date=start, 
    end_date=end, 
    frequency=freq, 
    location_label=False, 
    export_csv=True, 
    store_df=False
)
# Out:
# Retrieving weather data for Kuala+Lumpur
#
#
# Currently retrieving data for Kuala+Lumpur: from 2012-03-08 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.114894
# Currently retrieving data for Kuala+Lumpur: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.548665
# Currently retrieving data for Kuala+Lumpur: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.629514
# Currently retrieving data for Kuala+Lumpur: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.698663
# Currently retrieving data for Kuala+Lumpur: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.919896
# Currently retrieving data for Kuala+Lumpur: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.922151
# Currently retrieving data for Kuala+Lumpur: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.890178
# Currently retrieving data for Kuala+Lumpur: from 2012-10-01 to 2012-10-31
# ...
